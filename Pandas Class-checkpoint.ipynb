# %%
x1=10
x2=12
def h(x1,x2):
    return (x1+x2)
r=h(x1,x2)
print(r*10)
# Out:
# 220

# %%
arr = input().strip().split(' ')
print(arr)
# Out:
# 3 4 5
# ['3', '4', '5']

# %%
import pandas as pd
p=pd.DataFrame({'a':[1,2,3],'b':[3,4,5],'c':[6,7,8]},index=(0,1,2))
p.values
# Out:
# array([[1, 3, 6],
#        [2, 4, 7],
#        [3, 5, 8]], dtype=int64)

# %%
import numpy as np
l=[]
l.append(input())
arr=np.array(l)
print(arr)
# Out:
# 3 4 5 6 7 8
# ['3 4 5 6 7 8 ']

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')
data.head(2)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4

# %%
data.shape
# Out:
# (200, 5)

# %%
data['TV'].max
# Out:
# <bound method Series.max of 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
# 5        8.7
# 6       57.5
# 7      120.2
# 8        8.6
# 9      199.8
# 10      66.1
# 11     214.7
# 12      23.8
# 13      97.5
# 14     204.1
# 15     195.4
# 16      67.8
# 17     281.4
# 18      69.2
# 19     147.3
# 20     218.4
# 21     237.4
# 22      13.2
# 23     228.3
# 24      62.3
# 25     262.9
# 26     142.9
# 27     240.1
# 28     248.8
# 29      70.6
#        ...
# 170     50.0
# 171    164.5
# 172     19.6
# 173    168.4
# 174    222.4
# 175    276.9
# 176    248.4
# 177    170.2
# 178    276.7
# 179    165.6
# 180    156.6
# 181    218.5
# 182     56.2
# 183    287.6
# 184    253.8
# 185    205.0
# 186    139.5
# 187    191.1
# 188    286.0
# 189     18.7
# 190     39.5
# 191     75.5
# 192     17.2
# 193    166.8
# 194    149.7
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, dtype: float64>

# %%
import matplotlib.pyplot as plt
X=data['TV']
Y=data['sales']
plt.scatter(X,Y,color='#ff1142')
plt.show()

# %%
chips=pd.read_table('http://bit.ly/chiporders')
chips.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
chips.item_price.max()
# Out:
# '$9.39 '

# %%
chips.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chips.item_price.str.replace('$','')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#          ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# ...

# %%
chips.item_price.max()
# Out:
# '$9.39 '

# %%
chips.item_price=chips.item_price.str.replace('$','').astype(float)

# %%
chips.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
chips.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chips.item_price=chips.item_price.astype(float)

# %%
chips.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
len(chips.item_price)
# Out:
# 4622

# %%
chips.item_price=np.arange(0,4622)

# %%
chips.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN           0
# 1                                       [Clementine]           1
# 2                                            [Apple]           2
# 3                                                NaN           3
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...           4

# %%
s=chips.item_name.str.contains('Chips')

# %%
len(s)
# Out:
# 4622

# %%
chips[s]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# 15           8         1  Chips and Tomatillo-Green Chili Salsa
# 20          10         1                    Chips and Guacamole
# 25          13         1           Chips and Fresh Tomato Salsa
# 30          15         1  Chips and Tomatillo-Green Chili Salsa
# 32          16         1                          Side of Chips
# 37          18         1                    Chips and Guacamole
# 38          18         1  Chips and Tomatillo Green Chili Salsa
# 40          19         1                                  Chips
# 41          20         1                    Chips and Guacamole
# ...

# %%
chips_item=chips[s]
# Out:
# C:\Users\shash\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
chips_item.shape
# Out:
# (1084, 5)

# %%
chips.choice_description.str.contains('Apple').fillna(False)
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4592    False
# 4593    False
# 4594    False
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# 4600    False
# 4601    False
# 4602    False
# 4603    False
# 4604    False
# 4605    False
# 4606    False
# 4607    False
# 4608    False
# 4609    False
# 4610    False
# 4611    False
# 4612    False
# 4613    False
# 4614    False
# 4615    False
# 4616    False
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# ...

# %%
chips.choice_description.str.contains('Apple')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd94cdd10b19> in <module>()
# ----> 1 chips.choice_description.str.contains('Apple')
#
# NameError: name 'chips' is not defined

# %%
x=chips.choice_description.str.contains('Salsa').dropna()
len(x)
# Out:
# 0

# %%
chips.head()
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
#
#    choice_description  item_price
# 0                 NaN           0
# 3                 NaN           3
# 6                 NaN           6
# 10                NaN          10
# 14                NaN          14

# %%
header=['S.No.','age','gender','occupation','zip code']

# %%
m=pd.read_csv('http://bit.ly/movieusers',sep='|',names=header)

# %% [markdown]
# m.head()

# %%
m.head()
# Out:
#    S.No.  age gender  occupation zip code
# 0      1   24      M  technician    85711
# 1      2   53      F       other    94043
# 2      3   23      M      writer    32067
# 3      4   24      M  technician    43537
# 4      5   33      F       other    15213

# %%
m.columns=m.columns.str.replace('gender','GENDER')

# %%
m.head()
# Out:
#    S.No.  age GENDER  occupation zip code
# 0      1   24      M  technician    85711
# 1      2   53      F       other    94043
# 2      3   23      M      writer    32067
# 3      4   24      M  technician    43537
# 4      5   33      F       other    15213

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %%
movies.sort_values(['genre','duration'])
# Out:
#      star_rating                           title content_rating     genre  \
# 533          7.8                    Run Lola Run              R    Action
# 633          7.7                    The Warriors              R    Action
# 455          7.9                           Taken          PG-13    Action
# 685          7.7                     First Blood              R    Action
# 744          7.6     Mad Max 2: The Road Warrior              R    Action
# 619          7.7                Forbidden Planet         PASSED    Action
# 276          8.1            A Fistful of Dollars              R    Action
# 403          7.9                      Ying xiong          PG-13    Action
# 552          7.8                  Kung Fu Hustle              R    Action
# 740          7.6            The Raid: Redemption              R    Action
# 327          8.0    The Adventures of Robin Hood             PG    Action
# 515          7.8                     Dirty Harry              R    Action
# ...

# %% [markdown]
# movies.genre.str.contains('Action')

# %%
a=movies[movies.genre.str.contains('Action') | movies.genre.str.contains('Comedy')]

# %%
a.shape
# Out:
# (292, 6)

# %%
a[(a.duration>=150) & (a.star_rating>=8.5)]
# Out:
#     star_rating                  title content_rating   genre  duration  \
# 3           9.0        The Dark Knight          PG-13  Action       152
# 36          8.6    Saving Private Ryan              R  Action       169
# 43          8.5  The Dark Knight Rises          PG-13  Action       165
# 44          8.5              Gladiator              R  Action       155
# 60          8.5               3 Idiots          PG-13  Comedy       170
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 36     [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 43  [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 44  [u'Russell Crowe', u'Joaquin Phoenix', u'Conni...
# 60        [u'Aamir Khan', u'Madhavan', u'Mona Singh']

# %%
movies[movies.genre.isin(['Comedy','Action','Crime'])]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                          Star Wars
# 20           8.7                                         The Matrix
# 21           8.7                                        City of God
# 23           8.7                                 The Usual Suspects
# 25           8.6                                  Life Is Beautiful
# 28           8.6                             Leon: The Professional
# ...

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
len(movies.genre.unique())
# Out:
# 16
